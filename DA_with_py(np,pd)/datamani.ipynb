# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Projects\AIMLTutorial\data\data.csv")

# %%
df.head()
# Out:
#          Date Category  Value   Product  Sales Region
# 0  2023-01-01        A   28.0  Product1  754.0   East
# 1  2023-01-02        B   39.0  Product3  110.0  North
# 2  2023-01-03        C   32.0  Product2  398.0   East
# 3  2023-01-04        B    8.0  Product1  522.0   East
# 4  2023-01-05        B   26.0  Product3  869.0  North

# %%
#Last 5 rows
df.tail()
# Out:
#           Date Category  Value   Product  Sales Region
# 45  2023-02-15        B   99.0  Product2  599.0   West
# 46  2023-02-16        B    6.0  Product1  938.0  South
# 47  2023-02-17        B   69.0  Product3  143.0   West
# 48  2023-02-18        C   65.0  Product3  182.0  North
# 49  2023-02-19        C   11.0  Product3  708.0  North

# %%
#Statistics
df.describe()
# Out:
#            Value       Sales
# count  47.000000   46.000000
# mean   51.744681  557.130435
# std    29.050532  274.598584
# min     2.000000  108.000000
# 25%    27.500000  339.000000
# 50%    54.000000  591.500000
# 75%    70.000000  767.500000
# max    99.000000  992.000000

# %%
#Data Types
df.dtypes
# Out:
# Date         object
# Category     object
# Value       float64
# Product      object
# Sales       float64
# Region       object
# dtype: object

# %%
## Handling Missing Values
df.isnull()
# Out:
#      Date  Category  Value  Product  Sales  Region
# 0   False     False  False    False  False   False
# 1   False     False  False    False  False   False
# 2   False     False  False    False  False   False
# 3   False     False  False    False  False   False
# 4   False     False  False    False  False   False
# 5   False     False  False    False  False   False
# 6   False     False  False    False  False   False
# 7   False     False  False    False  False   False
# 8   False     False  False    False  False   False
# 9   False     False  False    False  False   False
# 10  False     False  False    False  False   False
# 11  False     False  False    False   True   False
# 12  False     False  False    False  False   False
# 13  False     False  False    False  False   False
# 14  False     False  False    False  False   False
# 15  False     False   True    False  False   False
# 16  False     False  False    False  False   False
# ...

# %%
##seeing like this is not a good idea
#Row wise
df.isnull().any(axis=1)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# 15     True
# 16    False
# 17     True
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28     True
# 29    False
# 30    False
# 31    False
# 32    False
# 33     True
# 34    False
# 35     True
# 36    False
# 37     True
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# dtype: bool

# %%
#Column wise
df.isnull().any()
# Out:
# Date        False
# Category    False
# Value        True
# Product     False
# Sales        True
# Region      False
# dtype: bool

# %%
#We can use sum
#By default column wise
df.isnull().sum()
# Out:
# Date        0
# Category    0
# Value       3
# Product     0
# Sales       4
# Region      0
# dtype: int64

# %%
#To repa;lce missing values with 0
df_filled = df.fillna(0)
df_filled
# Out:
#           Date Category  Value   Product  Sales Region
# 0   2023-01-01        A   28.0  Product1  754.0   East
# 1   2023-01-02        B   39.0  Product3  110.0  North
# 2   2023-01-03        C   32.0  Product2  398.0   East
# 3   2023-01-04        B    8.0  Product1  522.0   East
# 4   2023-01-05        B   26.0  Product3  869.0  North
# 5   2023-01-06        B   54.0  Product3  192.0   West
# 6   2023-01-07        A   16.0  Product1  936.0   East
# 7   2023-01-08        C   89.0  Product1  488.0   West
# 8   2023-01-09        C   37.0  Product3  772.0   West
# 9   2023-01-10        A   22.0  Product2  834.0   West
# 10  2023-01-11        B    7.0  Product1  842.0  North
# 11  2023-01-12        B   60.0  Product2    0.0   West
# 12  2023-01-13        A   70.0  Product3  628.0  South
# 13  2023-01-14        A   69.0  Product1  423.0   East
# 14  2023-01-15        A   47.0  Product2  893.0   West
# 15  2023-01-16        C    0.0  Product1  895.0  North
# ...

# %%
#filling missing values with mean
df['Salles_fillNA']  = df['Sales'].fillna(df['Sales'].mean())

# %%
df
# Out:
#           Date Category  Value   Product  Sales Region  Salles_fillNA
# 0   2023-01-01        A   28.0  Product1  754.0   East     754.000000
# 1   2023-01-02        B   39.0  Product3  110.0  North     110.000000
# 2   2023-01-03        C   32.0  Product2  398.0   East     398.000000
# 3   2023-01-04        B    8.0  Product1  522.0   East     522.000000
# 4   2023-01-05        B   26.0  Product3  869.0  North     869.000000
# 5   2023-01-06        B   54.0  Product3  192.0   West     192.000000
# 6   2023-01-07        A   16.0  Product1  936.0   East     936.000000
# 7   2023-01-08        C   89.0  Product1  488.0   West     488.000000
# 8   2023-01-09        C   37.0  Product3  772.0   West     772.000000
# 9   2023-01-10        A   22.0  Product2  834.0   West     834.000000
# 10  2023-01-11        B    7.0  Product1  842.0  North     842.000000
# 11  2023-01-12        B   60.0  Product2    NaN   West     557.130435
# ...

# %%
df.dtypes
# Out:
# Date              object
# Category          object
# Value            float64
# Product           object
# Sales            float64
# Region            object
# Salles_fillNA    float64
# dtype: object

# %%
#rename
df =df.rename(columns={'Date':'Sales Date'})
df.head()
# Out:
#    Sales Date Category  Value   Product  Sales Region  Sales_fillNA
# 0  2023-01-01        A   28.0  Product1  754.0   East         754.0
# 1  2023-01-02        B   39.0  Product3  110.0  North         110.0
# 2  2023-01-03        C   32.0  Product2  398.0   East         398.0
# 3  2023-01-04        B    8.0  Product1  522.0   East         522.0
# 4  2023-01-05        B   26.0  Product3  869.0  North         869.0

# %%
df = df.rename(columns = {'Salles_fillNA':'Sales_fillNA'})
df.head()
# Out:
#    Sales Date Category  Value   Product  Sales Region  Sales_fillNA
# 0  2023-01-01        A   28.0  Product1  754.0   East         754.0
# 1  2023-01-02        B   39.0  Product3  110.0  North         110.0
# 2  2023-01-03        C   32.0  Product2  398.0   East         398.0
# 3  2023-01-04        B    8.0  Product1  522.0   East         522.0
# 4  2023-01-05        B   26.0  Product3  869.0  North         869.0

# %%
#Chages dtypes
#convert SAles_fillnea to int

df['Value_new'] = df['Value'].fillna(df['Value'].mean()).astype(int)
df.head()
# Out:
#    Sales Date Category  Value   Product  Sales Region  Sales_fillNA  Value_new
# 0  2023-01-01        A   28.0  Product1  754.0   East         754.0         28
# 1  2023-01-02        B   39.0  Product3  110.0  North         110.0         39
# 2  2023-01-03        C   32.0  Product2  398.0   East         398.0         32
# 3  2023-01-04        B    8.0  Product1  522.0   East         522.0          8
# 4  2023-01-05        B   26.0  Product3  869.0  North         869.0         26

# %%
#Apply fuc on a column
df['Value_new'] = df['Value_new'].apply(lambda x:x*2)
df.head()
# Out:
#    Sales Date Category  Value   Product  Sales Region  Sales_fillNA  Value_new
# 0  2023-01-01        A   28.0  Product1  754.0   East         754.0         56
# 1  2023-01-02        B   39.0  Product3  110.0  North         110.0         78
# 2  2023-01-03        C   32.0  Product2  398.0   East         398.0         64
# 3  2023-01-04        B    8.0  Product1  522.0   East         522.0         16
# 4  2023-01-05        B   26.0  Product3  869.0  North         869.0         52

# %%
## Data aggregation and grouping
df.head()
# Out:
#    Sales Date Category  Value   Product  Sales Region  Sales_fillNA  Value_new
# 0  2023-01-01        A   28.0  Product1  754.0   East         754.0         56
# 1  2023-01-02        B   39.0  Product3  110.0  North         110.0         78
# 2  2023-01-03        C   32.0  Product2  398.0   East         398.0         64
# 3  2023-01-04        B    8.0  Product1  522.0   East         522.0         16
# 4  2023-01-05        B   26.0  Product3  869.0  North         869.0         52

# %%
group_mean = df.groupby('Product')['Value'].mean()

# %%
group_mean
# Out:
# Product
# Product1    46.214286
# Product2    52.800000
# Product3    55.166667
# Name: Value, dtype: float64

# %%
grouped_sum = df.groupby(['Product','Region'])['Value'].sum()
grouped_sum
# Out:
# Product   Region
# Product1  East      292.0
#           North       9.0
#           South     100.0
#           West      246.0
# Product2  East       56.0
#           North     127.0
#           South     181.0
#           West      428.0
# Product3  East      202.0
#           North     203.0
#           South     215.0
#           West      373.0
# Name: Value, dtype: float64

# %%
df.groupby(['Product','Region'])['Value'].mean()
# Out:
# Product   Region
# Product1  East      41.714286
#           North      4.500000
#           South     50.000000
#           West      82.000000
# Product2  East      28.000000
#           North     63.500000
#           South     60.333333
#           West      53.500000
# Product3  East      50.500000
#           North     40.600000
#           South     71.666667
#           West      62.166667
# Name: Value, dtype: float64

# %%
df.isnull().any()
# Out:
# Sales Date      False
# Category        False
# Value            True
# Product         False
# Sales            True
# Region          False
# Sales_fillNA    False
# Value_new       False
# dtype: bool

# %%
#find data type
df.dtypes
# Out:
# Sales Date       object
# Category         object
# Value           float64
# Product          object
# Sales           float64
# Region           object
# Sales_fillNA    float64
# Value_new         int64
# dtype: object

# %%
df.groupby(['Product','Region'])['Value'].agg(['mean','sum','count'])
# Out:
#                       mean    sum  count
# Product  Region
# Product1 East    41.714286  292.0      7
#          North    4.500000    9.0      2
#          South   50.000000  100.0      2
#          West    82.000000  246.0      3
# Product2 East    28.000000   56.0      2
#          North   63.500000  127.0      2
#          South   60.333333  181.0      3
#          West    53.500000  428.0      8
# Product3 East    50.500000  202.0      4
#          North   40.600000  203.0      5
#          South   71.666667  215.0      3
#          West    62.166667  373.0      6

# %%
## Agg functions multiple columns

df.groupby(['Product','Region']).agg({'Value':['mean','sum']})
# Out:
#                      Value
#                       mean    sum
# Product  Region
# Product1 East    41.714286  292.0
#          North    4.500000    9.0
#          South   50.000000  100.0
#          West    82.000000  246.0
# Product2 East    28.000000   56.0
#          North   63.500000  127.0
#          South   60.333333  181.0
#          West    53.500000  428.0
# Product3 East    50.500000  202.0
#          North   40.600000  203.0
#          South   71.666667  215.0
#          West    62.166667  373.0

# %%
## Merging and joining dataframes

df1 = pd.DataFrame({'Key': ['K0', 'K1', 'K2'],
                    'Value1' : ['V0', 'V1', 'V2'],
})
df2 = pd.DataFrame({'Key': ['K0', 'K1', 'K3'],
                    'Value2' : ['V4', 'V5', 'V6'],
})


df2
# Out:
#   Key Value2
# 0  K0     V4
# 1  K1     V5
# 2  K3     V6

# %%
df1
# Out:
#   Key Value1
# 0  K0     V0
# 1  K1     V1
# 2  K2     V2

# %%
## Merge
pd.merge(df1,df2,on='Key')
# Out:
#   Key Value1 Value2
# 0  K0     V0     V4
# 1  K1     V1     V5

# %%
pd.merge(df1,df2,on='Key',how='inner')
# Out:
#   Key Value1 Value2
# 0  K0     V0     V4
# 1  K1     V1     V5

# %%
pd.merge(df1,df2,on='Key',how='outer')
# Out:
#   Key Value1 Value2
# 0  K0     V0     V4
# 1  K1     V1     V5
# 2  K2     V2    NaN
# 3  K3    NaN     V6

# %%
pd.merge(df1,df2,on='Key',how='left')
# Out:
#   Key Value1 Value2
# 0  K0     V0     V4
# 1  K1     V1     V5
# 2  K2     V2    NaN

# %%
pd.merge(df1,df2,on='Key',how='right')
# Out:
#   Key Value1 Value2
# 0  K0     V0     V4
# 1  K1     V1     V5
# 2  K3    NaN     V6
